# %% [markdown]
# ## This is the Pandas and Matplotlib homework for GEOG 592.
# Name: Anna Horton
# ONYEN: arhorton
#
# #### This will be a mix of code and markdown cells so that I can answer the questions in the format that they are best answered!

# %% [markdown]
# ##### Question One:
# The df is the object and the method is the .head(); the .head() method uses dot notation.

# %% [markdown]
# ##### Question Two:
# My original answer: df.shape is a method.
#
# Correct:
# df.shape is an attribute. It stores information about the object. If the code does not include a parentheses, the code is referring to an attribute; only methods use parentheses to denote their correct symbology.

# %% [markdown]
# ##### Question Three:
# The dataset has 75 columns and 8 rows.

# %% [markdown]
# ##### Question Four:
# When a single dataframe column is called, usually by syntax like dataframe["Yes/No Response"], a pandas Series object is produced.

# %% [markdown]
# ##### Question Five:
# My original answer: an object is produced
#
# Correct:
# When multiple columns are called from the dataframe, the output is usually a pandas DataFrame of its own. The two columns together create a dataframe with values associated.

# %%
## Code for a few further questions!
import pandas as pd
parks = pd.DataFrame({"Park": ["Oak", "Pine", "Maple", "Cedar"], "Area": [12, 25, 18, 40], "Visitors": [120, 250, 180, 310]})
print(parks)
# Out:
#     Park  Area  Visitors
# 0    Oak    12       120
# 1   Pine    25       250
# 2  Maple    18       180
# 3  Cedar    40       310

# %% [markdown]
# ##### Question 6 and 7 are below.

# %%
## Question 6 answer
parks["Visitors"]
print(parks["Visitors"])

## Question 7 answer
parks[["Park", "Visitors"]]
print(parks[["Park", "Visitors"]])
# Out:
# 0    120
# 1    250
# 2    180
# 3    310
# Name: Visitors, dtype: int64
#     Park  Visitors
# 0    Oak       120
# 1   Pine       250
# 2  Maple       180
# 3  Cedar       310

# %% [markdown]
# ##### Question 8:
# parks.iloc[0] will return the zeroth row of the dataset, which in this case belongs to the Oak Park, its area and its visitors. The .iloc() method allows for the references to be called to by index position.

# %%
## Question 8 answer
parks.iloc[0]
# Out:
# Park        Oak
# Area         12
# Visitors    120
# Name: 0, dtype: object

# %% [markdown]
# ##### Question 9:
# The rows that are selected for in parks.iloc[1:4] are the first three rows. Though the fourth row appears to be included, it only selected the rows from 1 to 3 and the fourth is not included.

# %%
## Question 9 answer
parks.iloc[1:4]
# Out:
#     Park  Area  Visitors
# 1   Pine    25       250
# 2  Maple    18       180
# 3  Cedar    40       310

# %% [markdown]
# ##### Question Ten:
# The answer to question 10 is below. This code works because there are only three rows, so the four is not involved at all; the 2 starts the slicing and the slicing ends at the third row.

# %%
## Question 10 answer
# My original code: 
# parks.iloc[2:5[["Park", "Area"]]

# Correct answer
parks.iloc[2:4][["Park", "Area"]]
# Out:
#     Park  Area
# 2  Maple    18
# 3  Cedar    40

# %% [markdown]
# ##### Question 11:
# The answer to question 11 is below.

# %%
## Question 11 answer
mask = parks["Area"] > 20

# %% [markdown]
# ##### Question 12:
# The rows that are kept after using the mask/Boolean filter are only those that have an area larger than 20. In this case, that is only two parks: Pine and Cedar.

# %% [markdown]
# ##### Question 13:
# The answer to question 13 is below.

# %%
## Question 13 answer
# My original code
# large_parks = parks[mask]

# Correct answer
large_parks = parks[mask].copy()

# %% [markdown]
# ##### Question 14:
# The .copy() method is useful after filtering because it makes an individual copy of the filtered dataframe with its own memory. With the dataframe saved like that, any edits that are made to the new one do not affect what is stored in memory for the older one. It allows you to retrace your steps if needed.

# %% [markdown]
# ##### Question 15:
# The answer to question 15 is below.

# %%
## Question 15 answer
# My original code: parks.columns = parks[["Name", "Area_ha", "Annual Visitors"]]

# Correct answer
parks.columns = [["Name", "Area_ha", "Annual Visitors"]]

# %% [markdown]
# ##### Question 16:
# If the new column names only have two elements and the original dataframe has three columns, when the code tries to rename the columns, it will throw an error. There are a different number of objects within the lists that the code is trying to compare to each other, which leaves it confused and throwing an error.

# %%
## Code for the next few questions!
values = pd.Series(["12.5", "18.0", "missing", "22.5"])

# %% [markdown]
# ##### Question 17:
# This pandas.Series will likely store the numbers as strings because they each have the quotation marks around them. The Python string denotation syntax requires a ' or " around both sides of the element, and these numbers are represented in that format.

# %% [markdown]
# ##### Question 18:
# The answer to question 18 is below.

# %%
## Question 18 answer
# My original code
# pd.to_numeric(values = int), errors = "coerce")

# Correct answer
values = pd.to_numeric(values, errors = "coerce")
print(values)
# Out:
# 0    12.5
# 1    18.0
# 2     NaN
# 3    22.5
# dtype: float64

# %% [markdown]
# ##### Question 19:
# The "missing" value from the original values Series gets an NaN. This is code for "Not a number", which is what Python substites for anything

# %% [markdown]
# ##### Question 20:
# The is.na().sum() combination of methods spits out a sum of the total number of NA values within the rows. The .isna() method by itself returns a Boolean, where True denotes where there is an NA value and false in the opposite case.

# %% [markdown]
# ##### Question 21:
# The .dropna() method removes the rows that contain NA values from the dataframe entirely; the .fillna() method fills in where there are NA values with some other value that you select. There should be much thought that goes into eliminating or replacing NA values, as this alters the original dataframe and can change the results of the data analysis that is being conducted.

# %% [markdown]
# ##### Question 22:
# The answer to question 22 is below.

# %%
## checking the keys for the parks dataframe
parks.keys()
duplicated_cols = parks["Annual Visitors"].duplicated()
print(duplicated_cols)

parks.columns
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool
# MultiIndex([(           'Name',),
#             (        'Area_ha',),
#             ('Annual Visitors',)],
#            )

# %%
letters = {"A": [2, 3], "B:": [4, 5], "C": [6, 7]} # a dictionary from class

# %%
## Question 22 answer
# My original code 
# parks.sort("Visitors", ascending, na = False)

# Correct answer
sorted_parks = parks.sort_values(("Annual Visitors", ), ascending = False)
print(sorted_parks)
# Out:
#     Name Area_ha Annual Visitors
# 3  Cedar      40             310
# 1   Pine      25             250
# 2  Maple      18             180
# 0    Oak      12             120

# %% [markdown]
# ##### Question 23:
# The answer to question 23 is below.

# %%
## Question 23 answer
print(parks["Annual Visitors"].mean())
print(parks["Annual Visitors"].median())
# Out:
# Annual Visitors    215.0
# dtype: float64
# Annual Visitors    215.0
# dtype: float64

# %% [markdown]
# ##### Question 24:
# In a strongly right-skewed distribution, the median usually higher than the mean; there is syuch a wide range of data that the median gets pushed down to where the most amount of values are, while the mean is required to take in the higher values that will likely push it up above the median.

# %% [markdown]
# ##### Question 25:
# The bins = 10 code is to make the size of the histogram bins 10 units wide.

# %% [markdown]
# ##### Question 26:
# The 'ax' in a matplotlib graph is a matplolib graph object that each of the methods is called to to create the graph that the coder is envisioning. All of the dot notation methods below are determined to be related, or called with, this object.

# %% [markdown]
# ##### Question 27:
# ax.set_title();
# ax.set_xlabel();
# ax.set_ylabel()

# %% [markdown]
# ##### Question 28:
# The equal interval classification sorts the data that you are trying to make into intervals of equal numeric width (ex. if a dataset has 100 points, an equal interval classification scheme would have each category designated at 25, 50, 75, and 100). The quantiles distribution has the equal number of observations in each of the data categories. Correspoding to the previous example, there will be 20 observations in each of those categories detailed.

# %% [markdown]
# ##### Question 29:
# The answer to question 29 is below.

# %% [markdown]
# values = [5, 12, 3, 20]
#
# for v in values:
#     if v > 10:
#         print v
#     return values
#
# g_t_10: values[s]
#
# This is my original code - it is incorrect.

# %%
## Updated question 29 answer
values = [5, 12, 3, 20]

for value in values:
    if value > 10:
        print(value)

s = ["False", "True", "False", "True"]
g_t_ten = values[s] ## if the series were called S, would work if I had imported pandas but I haven't!
# Out:
# 12
# 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 9
#       5     if value > 10:
#       6         print(value)
#       7
#       8 s = ["False", "True", "False", "True"]
# ----> 9 g_t_ten = values[s] ## if the series were called S, would work if I had imported pandas but I haven't!
#
# TypeError: list indices must be integers or slices, not list
