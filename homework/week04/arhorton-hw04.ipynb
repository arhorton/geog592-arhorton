# %% [markdown]
# ### Homework 04 - Anna Horton
# This is the fourth homework from GEOG 592. My task is to use my cleaned CSV from last homework and utilize various Pandas functionalities on it to discern all of the relevant details of the data.

# %% [markdown]
# #### First task: use df.head(), df.shape, df.columns, df.types, df.info()
# I will import the data first and then use each of the following methods.

# %%
# also need to import and install pandas
import pandas as pd
import csv

filename = "cleaned_brownfields.csv"
df = pd.read_csv(filename)

type(df)
# Out:
# pandas.DataFrame

# %%
## df.head()
### This methods prints out the first five rows of the data.frame by default. 
df.head()
# Out:
#                        BF_Name BF_Acreage   County               Status  \
# 0            Hunt Manfacturing      18.38  Iredell  No Further Interest
# 1               Scott Aviation     13.265    Union             Recorded
# 2            Carolina Counters       2.64   Stanly  No Further Interest
# 3  TFI Finishing Building West       5.34  Forsyth      Active Eligible
# 4               Avondale Mills      14.05   Yancey      Active Eligible
#
#              x2             y2
# 0  1.428118e+06  749617.691245
# 1  1.534652e+06  452976.151984
# 2  1.574688e+06  558419.830203
# 3  1.632935e+06  861044.261699
# 4  1.019389e+06  803841.062457

# %%
## df.shape
### This functionality gives me the shape of the data.frame (rows and columns)
df.shape
# Out:
# (1583, 6)

# %%
## df.columns
### This functionality gives me the list of the columns in the dataframe. 
df.columns
# Out:
# Index(['BF_Name', 'BF_Acreage', 'County', 'Status', 'x2', 'y2'], dtype='str')

# %%
## df.dtypes
### This functionality gives me the data types of each of the columns and values within the dataframe. 
df.dtypes
# Out:
# BF_Name           str
# BF_Acreage        str
# County            str
# Status            str
# x2            float64
# y2            float64
# dtype: object

# %%
## df.info
### This functionality gives me a summary of the important information about this particular dataframe. 
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1583 entries, 0 to 1582
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BF_Name     1583 non-null   str
#  1   BF_Acreage  1507 non-null   str
#  2   County      1583 non-null   str
#  3   Status      1583 non-null   str
#  4   x2          1583 non-null   float64
#  5   y2          1583 non-null   float64
# dtypes: float64(2), str(4)
# memory usage: 74.3 KB

# %% [markdown]
# #### Second task: use a mask to remove some of the rows in my dataframe.
# This will filter out some of the rows in the dataframe to make it smaller and slightly easier to deal with.

# %%
df["Status"] == "Active Eligible"
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 1578     True
# 1579    False
# 1580    False
# 1581    False
# 1582    False
# Name: Status, Length: 1583, dtype: bool

# %%
## I am choosing to use the sites that are in counties that start w/ the letter C. 
active_status = df["Status"] == "Active Eligible" 
active_status.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: Status, dtype: bool

# %% [markdown]
# I went back in to my homework 3 (it was submitted on time) to pull out some more columns from the original file. I had filtered down so far that I was missing some key columns, so I want back in and coded for them to be pushed into the cleaned_brownfields file so that I could use them for this homework. That is why there were changes to my homework 3. I also moved my cleaned_brownfields CSV out of the data folder so that I could reference it in this Jupyter notebook, which is not in the data folder. No AI was used.
