# %% [markdown]
# ## Homework 2 - Anna Horton
# ### Tracing Acai Data in the Brazilian state of Para

# %% [markdown]
# ### First task: import the CSV

# %%
## task one: import the CSV

import csv

filename = "tabela1613.csv"

with open(filename, "r") as file: # sometimes will need to make sure that you put in the encoding as utf-8 depending on the special characters
    reader = csv.reader(file)
    for i in range(4):
        next(reader)
    header = next(reader) # allows for the headers to be the fifth row
    dict_reader = csv.DictReader(file, fieldnames = header)
    rows = list(dict_reader)

type(rows)
# Out:
# list

# %%
rows = rows[1:5539] # removed the last few rows of data, only a legend and other things so we don't need to include it anymore

# %% [markdown]
# ### Second task: Inspect the data and identify the columns

# %% [markdown]
# ##### The columns needed for this assignment are the area that is scheduled to be collected and the amount of acai that was collected in that area. These columns are named Cod. and Acai, as these depict the municipality that the acai was collected from and the amount of acai that was collected. Both should be of numeric data type, free of empty cells, and accurately represent the municipalities' collection.

# %% [markdown]
# ### Third task: filter the data so only the data that comes from the correct municipality are present

# %%
print(rows[0].keys()) # trying to diagnose my issue with the Municipio key
# Out:
# dict_keys(['Nível', 'Cód.', 'Município', 'Total', '', 'Açaí', ' '])

# %%
for i, row in enumerate(rows): # attempting to debug the code later on to make sure that all rows that were caught had the acai values associated with them
    if "Açaí" not in row:
        print(i, row)

# %%
for i, row in enumerate(rows): # debugging the Municipio situation (it kept giving me a key error)
    if "Município" not in row:
        print(i, row)

# %%
for i, row in enumerate(rows):
    if len(rows) != len(header):
        print(i, len(row), row)

## this code prints every row because there are six headers and seven categories (one is headerless)
### this is good information for later on when I am extracting specific columns
# Out:
# 0 7 {'Nível': 'MU', 'Cód.': '1100023', 'Município': 'Ariquemes (RO)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '9167', ' ': 'Quilogramas por Hectare'}
# 1 7 {'Nível': 'MU', 'Cód.': '1100031', 'Município': 'Cabixi (RO)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '-', ' ': 'Quilogramas por Hectare'}
# 2 7 {'Nível': 'MU', 'Cód.': '1100049', 'Município': 'Cacoal (RO)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '-', ' ': 'Quilogramas por Hectare'}
# 3 7 {'Nível': 'MU', 'Cód.': '1100056', 'Município': 'Cerejeiras (RO)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '-', ' ': 'Quilogramas por Hectare'}
# 4 7 {'Nível': 'MU', 'Cód.': '1100064', 'Município': 'Colorado do Oeste (RO)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '-', ' ': 'Quilogramas por Hectare'}
# 5 7 {'Nível': 'MU', 'Cód.': '1100072', 'Município': 'Corumbiara (RO)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '-', ' ': 'Quilogramas por Hectare'}
# ...

# %%
for i, row in enumerate(rows): # this code is checking for an empty municipio category AND if there is one, is the value None?
    if "Município" in row and row["Município"] is None:
        print(i, row)

# there is no result, so there are no rows that fit this condition

# %%
## this is the fixed code that filters for the PA municipality
pa_rows = [row for row in rows if "Município" in row and "(PA)" in row["Município"]]
for row in pa_rows:
    print(row)

## this code prints out all of the PA municipalities so that I can visually verify their presence
# Out:
# {'Nível': 'MU', 'Cód.': '1500107', 'Município': 'Abaetetuba (PA)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '5600', ' ': 'Quilogramas por Hectare'}
# {'Nível': 'MU', 'Cód.': '1500131', 'Município': 'Abel Figueiredo (PA)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '8000', ' ': 'Quilogramas por Hectare'}
# {'Nível': 'MU', 'Cód.': '1500206', 'Município': 'Acará (PA)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '12000', ' ': 'Quilogramas por Hectare'}
# {'Nível': 'MU', 'Cód.': '1500305', 'Município': 'Afuá (PA)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '-', ' ': 'Quilogramas por Hectare'}
# {'Nível': 'MU', 'Cód.': '1500347', 'Município': 'Água Azul do Norte (PA)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '10000', ' ': 'Quilogramas por Hectare'}
# {'Nível': 'MU', 'Cód.': '1500404', 'Município': 'Alenquer (PA)', 'Total': '..', '': 'Quilogramas por Hectare', 'Açaí': '4961', ' ': 'Quilogramas por Hectare'}
# ...

# %% [markdown]
# ### Fourth task: Keep only the columns containing the municipality code and the quantity of acai produced

# %%
## keeping only the columns of the municipality code and the quantity of acai produced
only_columns = ["Cód.", "Açaí"] 
filtered_fully = [{col: row[col] for col in only_columns} for row in pa_rows]

for row in filtered_fully:
    print(row)

len(filtered_fully) # allows me to know how many rows of data I am working with
# Out:
# {'Cód.': '1500107', 'Açaí': '5600'}
# {'Cód.': '1500131', 'Açaí': '8000'}
# {'Cód.': '1500206', 'Açaí': '12000'}
# {'Cód.': '1500305', 'Açaí': '-'}
# {'Cód.': '1500347', 'Açaí': '10000'}
# {'Cód.': '1500404', 'Açaí': '4961'}
# {'Cód.': '1500503', 'Açaí': '8000'}
# {'Cód.': '1500602', 'Açaí': '8000'}
# {'Cód.': '1500701', 'Açaí': '10000'}
# {'Cód.': '1500800', 'Açaí': '4185'}
# {'Cód.': '1500859', 'Açaí': '6271'}
# {'Cód.': '1500909', 'Açaí': '6444'}
# {'Cód.': '1500958', 'Açaí': '6000'}
# {'Cód.': '1501006', 'Açaí': '6000'}
# {'Cód.': '1501105', 'Açaí': '8800'}
# {'Cód.': '1501204', 'Açaí': '5750'}
# {'Cód.': '1501253', 'Açaí': '-'}
# {'Cód.': '1501303', 'Açaí': '7000'}
# {'Cód.': '1501402', 'Açaí': '4000'}
# {'Cód.': '1501451', 'Açaí': '5600'}
# {'Cód.': '1501501', 'Açaí': '3125'}
# {'Cód.': '1501576', 'Açaí': '6000'}
# {'Cód.': '1501600', 'Açaí': '11700'}
# {'Cód.': '1501709', 'Açaí': '6000'}
# {'Cód.': '1501725', 'Açaí': '6000'}
# {'Cód.': '1501758', 'Açaí': '6000'}
# ...

# %% [markdown]
# ### Fifth task: Check the selected data for issues like missing values, non-numeric values, unnecessary rows or columns, and data type

# %%
## checking the data for issues like missing values, non-numeric values, data type and unneccessary rows and columns
## as can be seen above, there are some rows where the acai produced is missing - ensure that those are removed

## checking for None values
for i, row in enumerate(filtered_fully):
    if "Cód." == None or "Açaí" == None:
        print(i, row)

## checking for empty values (the ... is the format that the empty cells were delineated by in this case; the hyphen means absolute zero)
for i, row in enumerate(filtered_fully):
    if row.get("Açaí") == "...": # including the row.get() functionality in here prevents a key error and allows me to search through each of the rows individually 
        print(i, row)

## checking for data type and non-numeric values in the column
not_num = []
for row in rows:
    try: 
        float(row["Açaí"])
    except ValueError:
        not_num.append(row["Açaí"])

print(not_num)

# removing the rows where the acai production value is missing
## the rows with the slash delineates an absolute zero value and we are keeping those
dots_only = ["..."]
filtered_fully = [row for row in filtered_fully if not any(value in dots_only for value in row.values())]
# Out:
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '...', '-', '-', '-', '-', '...', '-', '-', '-', '-', '...', 
# ...

# %% [markdown]
# ### All cleaning decisions are scattered throughout the file. I removed unnecssary columns (all columns that were not pertaining to the code and the amount of fruit produced in that region), rows where the Municipio wasn't present, empty columns and rows, and a variety of other decisions aimed at debugging that helped me to filter the data early on.

# %%
type(filtered_fully)
# Out:
# list

# %% [markdown]
# ### Seventh task: Export the cleaned data as a new CSV file

# %%
fieldnames = filtered_fully[0].keys()

with open("filtered_fully.csv", "w", newline="") as file: 
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(filtered_fully)

# %% [markdown]
# ### AI Usage Statement
# 1) I used Claude AI. I keep forgetting that ChatGPT's parent company, OpenAI, donates to Trump, so I am avoiding them.
# 2) I asked it to help mostly with debugging and formatting issues. I was attempting to utilize the code for importing CSVs that we had previously used in class, but given the oddity of the data's headers and our conversation in class about it, I wasn't able to use that code. I asked Claude for help with fixing that section so that my data would import correctly. I also asked it for help when I was trying to remove rows and edit the data itself. Given that the data imported as a CSV file, I was prone to thinking of it as a dictionary (which I am much more familiar and comfortable working with than lists) and I needed assistance with converting the dictionary formatting that I had written into a list format.
# 3) The parts of the code that it helped me develop were all coding sections (importing the CSV, cleaning and filtering the data, and checking for errors). I would write most of the code myself, find out where the issues were, attempt to diagnose them myself, and then pivot towards Claude to help me debug any issues that were arising.
# 4) The changes and corrections I made were mainly related to the formatting issues I mentioned earlier. In the first section, I fixed the formatting of the CSV importation code to account for the lack of headers in the first row and then reassign the data to the correct headers later on. In the third section, where we were filtering for only the Pará municipality, I input additional functions to debug the code that Claude suggested (I kept getting a KeyError that it helped me to diagnose) and corrected my existing code for filtering out the specific municipality. In the fourth section, I corrected the code that I had originally written that was geared towards the dictionary and list functionality that I am more familiar with; Claude helped me to better understand the row.get() function as well as a better way to search for the presence of rows that match a certain condition in my objects. And finally, in the last section, Claude helped me to alter the try/except code that I had already written to check for empty values, None values, and the like in the data (I utilized the code that I had written previously and we wrote in class as a template); I also asked it for help in eliminating rows that had empty Acai values as I truly had no idea how to do that with a CSV list.
